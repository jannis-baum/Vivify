# %% [markdown]
# # Vivify testing notebook
#
# This notebook can be used for testing the rendering in Vivify

# %% [markdown]
# ## Output types

# %% [markdown]
# ### Streams & ANSI

# %%
colors = ['black', 'red', 'green', 'yellow', 'blue', 'magenta', 'cyan', 'white']
for (i, c) in enumerate(colors):
    print(f'{c: >8}  \033[3{i}mfg_normal\033[0m  \033[4{i}mbg_normal\033[0m  \033[9{i}mfg_bright\033[0m  \033[10{i}mbg_bright\033[0m')
# Out:
#    black  fg_normal  bg_normal  fg_bright  bg_bright
#      red  fg_normal  bg_normal  fg_bright  bg_bright
#    green  fg_normal  bg_normal  fg_bright  bg_bright
#   yellow  fg_normal  bg_normal  fg_bright  bg_bright
#     blue  fg_normal  bg_normal  fg_bright  bg_bright
#  magenta  fg_normal  bg_normal  fg_bright  bg_bright
#     cyan  fg_normal  bg_normal  fg_bright  bg_bright
#    white  fg_normal  bg_normal  fg_bright  bg_bright

# %%
print('We also have to be careful escaping HTML like <span>hehe</span>')
# Out:
# We also have to be careful escaping HTML like <span>hehe</span>

# %% [markdown]
# ### Errors

# %%
def some_fun():
    raise Exception('Hehe')

def some_other_fun():
    some_fun()

some_other_fun()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 def some_other_fun():
#       5     some_fun()
# ----> 7 some_other_fun()
#
# Cell In[3], line 5, in some_other_fun()
#       4 def some_other_fun():
# ----> 5     some_fun()
#
# Cell In[3], line 2, in some_fun()
#       1 def some_fun():
# ----> 2     raise Exception('Hehe')
#
# Exception: Hehe

# %% [markdown]
# ### HTML & images

# %%
import pandas as pd
df = pd.DataFrame({ 'a': [1, 2, 3], 'b': [10, 20, 30] })
df
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df.plot(figsize=(1, 1))
# Out:
# <Axes: >
